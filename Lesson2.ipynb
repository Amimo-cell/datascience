# %% [markdown]
# <a href="https://colab.research.google.com/github/Amimo-cell/datascience/blob/main/Lesson2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import io
from google.colab import files

# %%
#Allows us to upload files from pc
data = files.upload()
# Out:
#      <input type="file" id="files-a892aee1-fbe8-4889-9b91-139176cfaf50" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a892aee1-fbe8-4889-9b91-139176cfaf50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#converting the file into a dataframe
airbnb_data = pd.read_csv(io.StringIO(data['airbnb.csv'].decode('utf-8')))
#view the dataframe
airbnb_data.head().T
# Out:
#                                           0                   1  \
# Listings id                           31840              222527
# Last year reviews                         6                   0
# Host since                       2011-02-07          2011-07-11
# Host is superhost                      Host           Superhost
# Host number of listings                44.0                 3.0
# Neighbourhood                Centro Storico             Rifredi
# Beds number                             1.0                 3.0
# Bedrooms number                         1.0                 2.0
# Property type                  Private room         Entire home
# Maximum allowed guests                    2                   4
# Price                                  89.0               300.0
# Total reviews                           128                 284
# Rating score                           4.65                4.85
# Accuracy score                         4.73                4.88
# ...

# %%
airbnb_data.describe()
# Out:
#         Listings id  Last year reviews  Host number of listings  \
# count  2.820470e+05      282047.000000            282047.000000
# mean   4.131513e+17          17.187639                31.222101
# std    4.559440e+17          22.029768               113.235177
# min    2.737000e+03           0.000000                 1.000000
# 25%    2.349391e+07           2.000000                 1.000000
# 50%    5.202756e+07           8.000000                 3.000000
# 75%    8.760335e+17          26.000000                10.000000
# max    1.243448e+18         926.000000              7243.000000
#
#          Beds number  Bedrooms number  Maximum allowed guests          Price  \
# count  282047.000000    282047.000000           282047.000000  282047.000000
# mean        2.050325         1.381422                3.604658     173.157004
# std         1.300188         0.730077                1.804754     736.260971
# min         0.000000         0.000000                1.000000       8.000000
# ...

# %%
airbnb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282047 entries, 0 to 282046
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Listings id              282047 non-null  int64
#  1   Last year reviews        282047 non-null  int64
#  2   Host since               282047 non-null  object
#  3   Host is superhost        282047 non-null  object
#  4   Host number of listings  282047 non-null  float64
#  5   Neighbourhood            282047 non-null  object
#  6   Beds number              282047 non-null  float64
#  7   Bedrooms number          282047 non-null  float64
#  8   Property type            282047 non-null  object
#  9   Maximum allowed guests   282047 non-null  int64
#  10  Price                    282047 non-null  float64
#  11  Total reviews            282047 non-null  int64
#  12  Rating score             282047 non-null  float64
# ...

# %%
# converting the host since data from object to date(int64)
#airbnb_data['Host since']= airbnb_data['Host since'].astype(datetime())
airbnb_data['Host since'] = pd.to_datetime(airbnb_data['Host since'])

# %%
airbnb_data['Host since'].dtype
# Out:
# dtype('<M8[ns]')

# %%
airbnb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282047 entries, 0 to 282046
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Listings id              282047 non-null  int64
#  1   Last year reviews        282047 non-null  int64
#  2   Host since               282047 non-null  datetime64[ns]
#  3   Host is superhost        282047 non-null  object
#  4   Host number of listings  282047 non-null  float64
#  5   Neighbourhood            282047 non-null  object
#  6   Beds number              282047 non-null  float64
#  7   Bedrooms number          282047 non-null  float64
#  8   Property type            282047 non-null  object
#  9   Maximum allowed guests   282047 non-null  int64
#  10  Price                    282047 non-null  float64
#  11  Total reviews            282047 non-null  int64
#  12  Rating score             282047 non-null  float64
# ...
