# %% [markdown]
# <a href="https://colab.research.google.com/github/Amimo-cell/datascience/blob/main/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io
from google.colab import files

# %%
#uploading files from pc
data = files.upload()
# Out:
#      <input type="file" id="files-812401a6-3cb2-40c6-9b55-19c8dde3c090" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-812401a6-3cb2-40c6-9b55-19c8dde3c090">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#converting the file into a dataframe
data= pd.read_csv(io.StringIO(data['uae_real_estate_2024 (1).csv'].decode('utf-8')))
#view the dataframe
data.head()
# Out:
#                                               title  \
# 0               Great ROI I High Floor I Creek View
# 1  Full Sea View | Beach Life | Brand New Residence
# 2          Green Belt | Corner Unit | Spacious Plot
# 3          2BR+Study | Near Pool and Park | Private
# 4            Vacant | Well Maintained | Area Expert
#
#                             displayAddress bathrooms bedrooms  \
# 0     Binghatti Canal, Business Bay, Dubai         3        2
# 1  La Vie, Jumeirah Beach Residence, Dubai         3        2
# 2  La Rosa 6, Villanova, Dubai Land, Dubai         3        4
# 3           Springs 15, The Springs, Dubai         3        2
# 4      Noor Townhouses, Town Square, Dubai         3        3
#
#                 addedOn                  type    price  verified  \
# 0  2024-08-14T12:02:53Z  Residential for Sale  2500000      True
# 1  2024-08-13T05:45:16Z  Residential for Sale  7200000      True
# 2  2024-08-14T06:24:28Z  Residential for Sale  3600000      True
# ...

# %%
data.head().T
# Out:
#                                                                 0  \
# title                         Great ROI I High Floor I Creek View
# displayAddress               Binghatti Canal, Business Bay, Dubai
# bathrooms                                                       3
# bedrooms                                                        2
# addedOn                                      2024-08-14T12:02:53Z
# type                                         Residential for Sale
# price                                                     2500000
# verified                                                     True
# priceDuration                                                sell
# sizeMin                                                 1323 sqft
# furnishing                                                     NO
# description     MNA Properties is delighted to offer this apar...
#
#                                                                 1  \
# ...

# %%
import sklearn as sk

# %%
pip install scikit-learn

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
from sklearn.preprocessing import StandardScaler
SCALE=StandardScaler()

# %%
SCALE.fit(data[['sizeMin','furnishing']])
scaled_data = SCALE.transform(data[['sizeMin', 'furnishing']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-c4bb562e7c5c> in <cell line: 0>()
# ----> 1 SCALE.fit(data[['sizeMin','furnishing']])
#       2 scaled_data = SCALE.transform(data[['sizeMin', 'furnishing']])
#
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     892         # Reset internal state before fitting
#     893         self._reset()
# --> 894         return self.partial_fit(X, y, sample_weight)
#     895
#     896     @_fit_context(prefer_skip_nested_validation=True)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# ...

# %%
# Extract numerical part from 'sizeMin' and convert to float
data['sizeMin'] = data['sizeMin'].str.extract('(\d+)').astype(float)
# Extract numerical part from 'sizeMin' and convert to float

SCALE.fit(data[['sizeMin', 'furnishing']])
scaled_data = SCALE.transform(data[['sizeMin', 'furnishing']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-c4e27ee9f4d0> in <cell line: 0>()
#       1 # Extract numerical part from 'sizeMin' and convert to float
# ----> 2 data['sizeMin'] = data['sizeMin'].str.extract('(\d+)').astype(float)
#       3 # Extract numerical part from 'sizeMin' and convert to float
#       4
#       5 SCALE.fit(data[['sizeMin', 'furnishing']])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# ...

# %%
# Assuming 'sizeMin' initially contains mixed data (e.g., "1200 sqft")

# Check if the column is already numeric before trying to extract it
if data['sizeMin'].dtype == object:
    # Extract numerical part and convert to float only if it's a string
    data['sizeMin'] = data['sizeMin'].str.extract('(\d+)').astype(float)
else:
    print("sizeMin is already numeric, skipping str.extract")

SCALE.fit(data[['sizeMin','furnishing']])
scaled_data = SCALE.transform(data[['sizeMin', 'furnishing']])
# Out:
# sizeMin is already numeric, skipping str.extract
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-5547d58e34f3> in <cell line: 0>()
#       8     print("sizeMin is already numeric, skipping str.extract")
#       9
# ---> 10 SCALE.fit(data[['sizeMin', 'furnishing']])
#      11 scaled_data = SCALE.transform(data[['sizeMin', 'furnishing']])
#
# /usr/local/lib/python3.11/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     892         # Reset internal state before fitting
#     893         self._reset()
# --> 894         return self.partial_fit(X, y, sample_weight)
#     895
#     896     @_fit_context(prefer_skip_nested_validation=True)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# ...

# %%
print(data.dtypes)
# Out:
# title              object
# displayAddress     object
# bathrooms          object
# bedrooms           object
# addedOn            object
# type               object
# price               int64
# verified             bool
# priceDuration      object
# sizeMin           float64
# furnishing         object
# description        object
# dtype: object

# %%
data['sizeMin'] = data['sizeMin'].astype(int)

# %%
from sklearn.preprocessing import OneHotEncoder
data = pd.DataFrame({'furnishing': ['YES', 'NO', 'PARTLY']})
encoder = OneHotEncoder(drop='first', sparse_output=False)
encoded_data = encoder.fit_transform(data[['furnishing']])

# %%
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(['furnishing']))
result_df = pd.concat([data, encoded_df], axis=1)
print(result_df)
# Out:
#   furnishing  furnishing_PARTLY  furnishing_YES
# 0        YES                0.0             1.0
# 1         NO                0.0             0.0
# 2     PARTLY                1.0             0.0

# %%
data.columns = data.columns.str.strip()

# %%
data.rename(columns={'Size Min': 'sizeMin'}, inplace=True)

# %%
data['sizeMin'] = pd.to_numeric(data['sizeMin'], errors='coerce')
data['furnishing'] = pd.to_numeric(data['furnishing'], errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sizeMin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-4dc4e0ed93b0> in <cell line: 0>()
# ----> 1 data['sizeMin'] = pd.to_numeric(data['sizeMin'], errors='coerce')
# ...

# %%
SCALE = StandardScaler()
SCALE.fit(data[['sizeMin', 'furnishing']])
scaled_data = SCALE.transform(data[['sizeMin', 'furnishing']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-107286e2f15a> in <cell line: 0>()
#       1 SCALE = StandardScaler()
# ----> 2 SCALE.fit(data[['sizeMin', 'furnishing']])
#       3 scaled_data = SCALE.transform(data[['sizeMin', 'furnishing']])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
# ...

# %%
data = data.apply(pd.to_numeric, errors='coerce')

# %%
SCALE = StandardScaler()
SCALE.fit(data[['sizeMin', 'furnishing']])
scaled_data = SCALE.transform(data[['sizeMin', 'furnishing']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-107286e2f15a> in <cell line: 0>()
#       1 SCALE = StandardScaler()
# ----> 2 SCALE.fit(data[['sizeMin', 'furnishing']])
#       3 scaled_data = SCALE.transform(data[['sizeMin', 'furnishing']])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
# ...
