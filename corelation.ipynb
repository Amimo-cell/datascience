# %% [markdown]
# <a href="https://colab.research.google.com/github/Amimo-cell/datascience/blob/main/corelation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io
from google.colab import files

# %%
data=files.upload()
# Out:
#      <input type="file" id="files-c45c512f-e852-47f2-b3b8-4a4db3714388" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c45c512f-e852-47f2-b3b8-4a4db3714388">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#converting the file into a dataframe
data= pd.read_csv(io.StringIO(data['car_price_dataset (1).csv'].decode('utf-8')))
#view the dataframe
data.head().T
# Out:
#                    0          1          2         3               4
# Brand            Kia  Chevrolet   Mercedes      Audi      Volkswagen
# Model            Rio     Malibu        GLA        Q5            Golf
# Year            2020       2012       2020      2023            2003
# Engine_Size      4.2        2.0        4.2       2.0             2.6
# Fuel_Type     Diesel     Hybrid     Diesel  Electric          Hybrid
# Transmission  Manual  Automatic  Automatic    Manual  Semi-Automatic
# Mileage       289944       5356     231440    160971          286618
# Doors              3          2          4         2               3
# Owner_Count        5          3          2         1               3
# Price           8501      12092      11171     11780            2867

# %%
sns.regplot(x='Year',y='Price', data=data)
plt.ylim(0,)
# Out:
# (0.0, 19116.05)

# %%
sns.regplot(x='Owner_Count',y='Price', data=data)
plt.ylim(0,)
# Out:
# (0.0, 19116.05)

# %%
sns.regplot(x='Doors',y='Price', data=data)
plt.ylim(0,)
# Out:
# (0.0, 19116.05)

# %%
sns.regplot(x='Price',y='Mileage', data=data)
plt.ylim(0,)
# Out:
# (0.0, 314943.1)
